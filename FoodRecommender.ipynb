# %% [markdown]
# <a href="https://colab.research.google.com/github/Albrrr/Food-Recommender/blob/quantized/FoodRecommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Food Recommender Backend Hosting
# - We are using colab for a more powerful GPU

# %% [markdown]
# Clone repo

# %%
# !git clone https://github.com/Albrrr/Food-Recommender.git
# %cd Food-Recommender
# Out:
# Cloning into 'Food-Recommender'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 98 (delta 40), reused 67 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 6.73 MiB | 14.99 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# /content/Food-Recommender

# %% [markdown]
# Install Dependencies

# %%
# !pip install -r backend/requirements.txt
# Out:
# /content/Food-Recommender
# ...

# %% [markdown]
# Get tokens from secrets

# %%
from google.colab import userdata
import os

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
os.environ["MODEL_NAME"] = "hugging-quants/Meta-Llama-3.1-8B-Instruct-AWQ-INT4"
# 2. Retrieve Hugging Face token from Colab secrets
try:
    hf_token = userdata.get('HF_TOKEN')
    if not hf_token:
        raise ValueError("HF_TOKEN not found in Colab secrets.")
    print("Hugging Face token successfully retrieved from Colab secrets.")
except Exception as e:
    print(f"Error retrieving HF_TOKEN from Colab secrets: {e}")
    print("Please ensure you have set the HF_TOKEN in Colab secrets as per the instructions above.")
    hf_token = None # Ensure hf_token is None if retrieval fails

os.environ["HF_TOKEN"] = hf_token
os.environ["NGROK_AUTHTOKEN"] = userdata.get("NGROK_AUTHTOKEN")
os.environ["USE_NGROK"] = "1"
# Out:
# Hugging Face token successfully retrieved from Colab secrets.

# %% [markdown]
# Start backend

# %%
# !python backend/colab_run.py
# Out:
# Public URL: https://anopisthographically-teensy-milan.ngrok-free.dev
# Set your frontend API base to this URL (no trailing slash).
# INFO:     Started server process [2109]
# INFO:     Waiting for application startup.
# /content/Food-Recommender/backend/app.py:50: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# 2026-01-09 02:39:40.244010: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
