# %% [markdown]
# <a href="https://colab.research.google.com/github/Albrrr/Food-Recommender/blob/main/FoodRecommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Food Recommender Backend Hosting
# - We are using colab for a more powerful GPU

# %% [markdown]
# Clone repo

# %%
# !git clone https://github.com/Albrrr/Food-Recommender.git
# %cd Food-Recommender
# Out:
# Cloning into 'Food-Recommender'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 44 (delta 9), reused 39 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 1.97 MiB | 22.43 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/Food-Recommender/Food-Recommender

# %% [markdown]
# Install Dependencies

# %%
# !pip install -r backend/requirements.txt
# Out:
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (from -r backend/requirements.txt (line 1)) (0.123.10)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from -r backend/requirements.txt (line 2)) (0.38.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r backend/requirements.txt (line 3)) (2.9.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r backend/requirements.txt (line 4)) (4.57.3)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (from -r backend/requirements.txt (line 5)) (5.2.0)
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (from -r backend/requirements.txt (line 6)) (1.2.0)
# Collecting langchain-community (from -r backend/requirements.txt (line 7))
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting faiss-cpu (from -r backend/requirements.txt (line 8))
#   Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# Collecting pyngrok (from -r backend/requirements.txt (line 9))
#   Downloading pyngrok-7.5.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from -r backend/requirements.txt (line 10)) (1.12.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from -r backend/requirements.txt (line 11)) (0.2.1)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi->-r backend/requirements.txt (line 1)) (0.50.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from fastapi->-r backend/requirements.txt (line 1)) (2.12.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi->-r backend/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi->-r backend/requirements.txt (line 1)) (0.0.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn->-r backend/requirements.txt (line 2)) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn->-r backend/requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r backend/requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r backend/requirements.txt (line 4)) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r backend/requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r backend/requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers->-r backend/requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->-r backend/requirements.txt (line 4)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers->-r backend/requirements.txt (line 4)) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r backend/requirements.txt (line 4)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->-r backend/requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers->-r backend/requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r backend/requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r backend/requirements.txt (line 5)) (1.16.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from langchain->-r backend/requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langchain->-r backend/requirements.txt (line 6)) (1.0.5)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community->-r backend/requirements.txt (line 7))
#   Downloading langchain_classic-1.0.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r backend/requirements.txt (line 7)) (2.0.45)
# Collecting requests (from transformers->-r backend/requirements.txt (line 4))
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r backend/requirements.txt (line 7)) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r backend/requirements.txt (line 7)) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community->-r backend/requirements.txt (line 7))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r backend/requirements.txt (line 7)) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r backend/requirements.txt (line 7)) (0.4.59)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community->-r backend/requirements.txt (line 7)) (0.4.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->-r backend/requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r backend/requirements.txt (line 7)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r backend/requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r backend/requirements.txt (line 7)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r backend/requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r backend/requirements.txt (line 7)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r backend/requirements.txt (line 7)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r backend/requirements.txt (line 7)) (1.22.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r backend/requirements.txt (line 7))
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r backend/requirements.txt (line 7))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers->-r backend/requirements.txt (line 4)) (1.2.0)
# Collecting langchain-core<2.0.0,>=1.2.1 (from langchain->-r backend/requirements.txt (line 6))
#   Downloading langchain_core-1.2.5-py3-none-any.whl.metadata (3.7 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community->-r backend/requirements.txt (line 7))
#   Downloading langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain->-r backend/requirements.txt (line 6)) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain->-r backend/requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r backend/requirements.txt (line 6)) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r backend/requirements.txt (line 6)) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r backend/requirements.txt (line 6)) (0.3.0)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain->-r backend/requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community->-r backend/requirements.txt (line 7)) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community->-r backend/requirements.txt (line 7)) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community->-r backend/requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community->-r backend/requirements.txt (line 7)) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r backend/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r backend/requirements.txt (line 1)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r backend/requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community->-r backend/requirements.txt (line 7)) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r backend/requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r backend/requirements.txt (line 4)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r backend/requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers->-r backend/requirements.txt (line 4)) (2025.11.12)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community->-r backend/requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<0.51.0,>=0.40.0->fastapi->-r backend/requirements.txt (line 1)) (4.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r backend/requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r backend/requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->-r backend/requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->-r backend/requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community->-r backend/requirements.txt (line 7)) (1.0.9)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain->-r backend/requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain->-r backend/requirements.txt (line 6)) (1.12.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r backend/requirements.txt (line 7))
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 30.5 MB/s eta 0:00:00
# Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 90.1 MB/s eta 0:00:00
# Downloading pyngrok-7.5.0-py3-none-any.whl (24 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.4 MB/s eta 0:00:00
# Downloading langchain_core-1.2.5-py3-none-any.whl (484 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 33.4 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.7 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.5 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: requests, pyngrok, mypy-extensions, marshmallow, faiss-cpu, typing-inspect, dataclasses-json, langchain-core, langchain-text-splitters, langchain-classic, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.1
#     Uninstalling langchain-core-1.2.1:
#       Successfully uninstalled langchain-core-1.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# Successfully installed dataclasses-json-0.6.7 faiss-cpu-1.13.2 langchain-classic-1.0.1 langchain-community-0.4.1 langchain-core-1.2.5 langchain-text-splitters-1.1.0 marshmallow-3.26.2 mypy-extensions-1.1.0 pyngrok-7.5.0 requests-2.32.5 typing-inspect-0.9.0

# %% [markdown]
# Get tokens from secrets

# %%
from google.colab import userdata
import os

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
os.environ["MODEL_NAME"] = "meta-llama/Meta-Llama-3-8B-Instruct"
# 2. Retrieve Hugging Face token from Colab secrets
try:
    hf_token = userdata.get('HF_TOKEN')
    if not hf_token:
        raise ValueError("HF_TOKEN not found in Colab secrets.")
    print("Hugging Face token successfully retrieved from Colab secrets.")
except Exception as e:
    print(f"Error retrieving HF_TOKEN from Colab secrets: {e}")
    print("Please ensure you have set the HF_TOKEN in Colab secrets as per the instructions above.")
    hf_token = None # Ensure hf_token is None if retrieval fails

os.environ["HF_TOKEN"] = hf_token
os.environ["NGROK_AUTHTOKEN"] = userdata.get("NGROK_AUTHTOKEN")
os.environ["USE_NGROK"] = "1"
# Out:
# Hugging Face token successfully retrieved from Colab secrets.

# %% [markdown]
# Start backend

# %%
# !python backend/colab_run.py
# Out:
# Public URL: https://phenotypically-multiperforate-rodolfo.ngrok-free.dev
# Set your frontend API base to this URL (no trailing slash).
# INFO:     Started server process [1556]
# INFO:     Waiting for application startup.
# /content/Food-Recommender/Food-Recommender/backend/app.py:50: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# 2025-12-29 09:26:05.873692: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767000365.895930    1556 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767000365.902225    1556 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767000365.920744    1556 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767000365.920780    1556 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767000365.920783    1556 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767000365.920785    1556 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-29 09:26:05.926929: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# modules.json: 100% 349/349 [00:00<00:00, 2.72MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 1.02MB/s]
# README.md: 10.5kB [00:00, 17.8MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 527kB/s]
# config.json: 100% 612/612 [00:00<00:00, 5.82MB/s]
# model.safetensors: 100% 90.9M/90.9M [00:00<00:00, 140MB/s]
# tokenizer_config.json: 100% 350/350 [00:00<00:00, 2.70MB/s]
# vocab.txt: 232kB [00:00, 11.9MB/s]
# tokenizer.json: 466kB [00:00, 30.2MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 916kB/s]
# config.json: 100% 190/190 [00:00<00:00, 1.46MB/s]
# tokenizer_config.json: 100% 51.0k/51.0k [00:00<00:00, 130MB/s]
# tokenizer.json: 100% 9.09M/9.09M [00:00<00:00, 45.8MB/s]
# special_tokens_map.json: 100% 73.0/73.0 [00:00<00:00, 582kB/s]
# config.json: 100% 654/654 [00:00<00:00, 4.80MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 100% 23.9k/23.9k [00:00<00:00, 102MB/s]
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
#
#
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
#
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 816k/4.92G [00:00<1:05:50, 1.24MB/s]
#
#
#
# model-00002-of-00004.safetensors:   0% 500k/5.00G [00:00<2:31:13, 551kB/s]
#
#
# model-00004-of-00004.safetensors:   1% 14.6M/1.17G [00:01<01:20, 14.3MB/s]
# model-00003-of-00004.safetensors:   1% 67.8M/4.92G [00:01<01:12, 67.0MB/s]
#
# model-00001-of-00004.safetensors:   0% 19.7k/4.98G [00:01<108:01:30, 12.8kB/s]
# model-00003-of-00004.safetensors:   4% 202M/4.92G [00:01<00:28, 163MB/s]
#
# model-00001-of-00004.safetensors:   0% 27.9k/4.98G [00:01<77:49:48, 17.8kB/s]
# model-00003-of-00004.safetensors:   8% 403M/4.92G [00:01<00:12, 357MB/s]
#
#
# model-00004-of-00004.safetensors:   2% 23.1M/1.17G [00:01<01:30, 12.7MB/s]
# model-00003-of-00004.safetensors:  11% 537M/4.92G [00:01<00:09, 455MB/s]
#
# model-00001-of-00004.safetensors:   0% 36.6k/4.98G [00:02<73:37:57, 18.8kB/s]
# model-00003-of-00004.safetensors:  14% 672M/4.92G [00:02<00:08, 486MB/s]
#
#
#
# model-00002-of-00004.safetensors:   1% 67.6M/5.00G [00:02<02:16, 36.2MB/s]
#
# model-00001-of-00004.safetensors:   0% 58.0k/4.98G [00:02<36:42:09, 37.7kB/s]
#
#
#
# model-00002-of-00004.safetensors:   3% 135M/5.00G [00:02<01:04, 75.2MB/s]
#
#
# model-00004-of-00004.safetensors:   8% 90.6M/1.17G [00:02<00:24, 44.6MB/s]
# model-00003-of-00004.safetensors:  16% 806M/4.92G [00:02<00:10, 399MB/s]
#
#
#
# model-00002-of-00004.safetensors:   4% 202M/5.00G [00:02<00:44, 107MB/s]
#
# model-00001-of-00004.safetensors:   0% 67.2k/4.98G [00:03<58:19:06, 23.7kB/s]
# model-00003-of-00004.safetensors:  19% 940M/4.92G [00:03<00:11, 361MB/s]
#
#
# model-00004-of-00004.safetensors:  14% 158M/1.17G [00:03<00:16, 59.9MB/s]
#
#
#
# model-00002-of-00004.safetensors:   5% 269M/5.00G [00:03<00:45, 103MB/s]
#
# model-00001-of-00004.safetensors:   0% 80.7k/4.98G [00:03<53:27:43, 25.9kB/s]
#
#
#
# model-00002-of-00004.safetensors:   7% 336M/5.00G [00:03<00:34, 134MB/s]
#
# model-00001-of-00004.safetensors:   0% 98.6k/4.98G [00:03<37:02:01, 37.3kB/s]
# model-00003-of-00004.safetensors:  20% 1.01G/4.92G [00:03<00:15, 253MB/s]
#
#
#
# model-00002-of-00004.safetensors:   8% 403M/5.00G [00:03<00:25, 183MB/s]
#
# model-00001-of-00004.safetensors:   0% 107k/4.98G [00:06<116:44:39, 11.8kB/s]
#
#
# model-00004-of-00004.safetensors:  19% 225M/1.17G [00:06<00:25, 36.4MB/s]
#
#
#
# model-00002-of-00004.safetensors:  11% 537M/5.00G [00:06<00:52, 84.8MB/s]
#
# model-00001-of-00004.safetensors:   0% 157k/4.98G [00:06<45:27:01, 30.4kB/s]
#
#
#
# model-00002-of-00004.safetensors:  15% 740M/5.00G [00:06<00:26, 158MB/s]
# model-00003-of-00004.safetensors:  22% 1.08G/4.92G [00:06<00:44, 85.5MB/s]
#
#
#
# model-00002-of-00004.safetensors:  17% 874M/5.00G [00:06<00:18, 218MB/s]
#
# model-00001-of-00004.safetensors:   0% 182k/4.98G [00:06<37:33:11, 36.8kB/s]
#
#
#
# model-00002-of-00004.safetensors:  19% 941M/5.00G [00:06<00:17, 234MB/s]
# model-00003-of-00004.safetensors:  23% 1.14G/4.92G [00:06<00:38, 97.5MB/s]
#
# model-00001-of-00004.safetensors:   0% 205k/4.98G [00:07<32:18:33, 42.8kB/s]
#
#
#
# model-00002-of-00004.safetensors:  21% 1.07G/5.00G [00:07<00:15, 255MB/s]
# model-00003-of-00004.safetensors:  25% 1.21G/4.92G [00:07<00:34, 107MB/s]
#
#
# model-00004-of-00004.safetensors:  29% 336M/1.17G [00:07<00:15, 53.5MB/s]
#
# model-00001-of-00004.safetensors:   0% 221k/4.98G [00:07<31:31:04, 43.9kB/s]
# model-00003-of-00004.safetensors:  26% 1.28G/4.92G [00:07<00:27, 130MB/s]
#
#
#
# model-00002-of-00004.safetensors:  24% 1.21G/5.00G [00:07<00:12, 295MB/s]
# model-00003-of-00004.safetensors:  29% 1.41G/4.92G [00:07<00:16, 207MB/s]
#
#
# model-00004-of-00004.safetensors:  31% 363M/1.17G [00:07<00:14, 57.4MB/s]
#
# model-00001-of-00004.safetensors:   0% 230k/4.98G [00:07<31:13:39, 44.3kB/s]
#
# model-00001-of-00004.safetensors:   0% 249k/4.98G [00:07<25:44:12, 53.7kB/s]
# model-00003-of-00004.safetensors:  30% 1.48G/4.92G [00:07<00:15, 217MB/s]
#
#
#
# model-00002-of-00004.safetensors:  26% 1.28G/5.00G [00:07<00:15, 236MB/s]
#
# model-00001-of-00004.safetensors:   0% 274k/4.98G [00:10<66:34:57, 20.8kB/s]
#
#
# model-00004-of-00004.safetensors:  37% 430M/1.17G [00:10<00:18, 39.6MB/s]
# model-00003-of-00004.safetensors:  31% 1.54G/4.92G [00:10<00:42, 79.6MB/s]
#
# model-00001-of-00004.safetensors:   1% 67.3M/4.98G [00:10<03:31, 23.2MB/s]
#
#
# model-00004-of-00004.safetensors:  43% 497M/1.17G [00:10<00:13, 50.0MB/s]
#
#
#
# model-00002-of-00004.safetensors:  28% 1.41G/5.00G [00:10<00:36, 97.1MB/s]
#
#
# model-00004-of-00004.safetensors:  54% 631M/1.17G [00:10<00:05, 93.7MB/s]
#
#
#
# model-00002-of-00004.safetensors:  31% 1.54G/5.00G [00:10<00:24, 139MB/s]
# model-00003-of-00004.safetensors:  33% 1.61G/4.92G [00:11<00:40, 81.4MB/s]
#
# model-00001-of-00004.safetensors:   3% 134M/4.98G [00:11<01:34, 51.2MB/s]
# model-00003-of-00004.safetensors:  34% 1.68G/4.92G [00:11<00:31, 102MB/s]
#
#
# model-00004-of-00004.safetensors:  66% 766M/1.17G [00:11<00:02, 138MB/s]
#
#
# model-00004-of-00004.safetensors:  77% 900M/1.17G [00:11<00:01, 204MB/s]
#
#
# model-00004-of-00004.safetensors:  83% 967M/1.17G [00:11<00:00, 208MB/s]
#
#
# model-00004-of-00004.safetensors:  89% 1.03G/1.17G [00:11<00:00, 215MB/s]
# model-00003-of-00004.safetensors:  37% 1.81G/4.92G [00:12<00:24, 125MB/s]
#
#
#
# model-00002-of-00004.safetensors:  32% 1.61G/5.00G [00:11<00:29, 115MB/s]
#
#
# model-00004-of-00004.safetensors:  94% 1.10G/1.17G [00:14<00:00, 83.3MB/s]
# model-00003-of-00004.safetensors:  38% 1.88G/4.92G [00:14<00:43, 69.8MB/s]
#
#
#
# model-00002-of-00004.safetensors:  34% 1.68G/5.00G [00:14<00:47, 70.0MB/s]
# model-00003-of-00004.safetensors:  41% 2.01G/4.92G [00:14<00:25, 113MB/s]
#
#
#
# model-00002-of-00004.safetensors:  36% 1.81G/5.00G [00:14<00:29, 108MB/s]
# model-00003-of-00004.safetensors:  44% 2.15G/4.92G [00:14<00:16, 168MB/s]
# model-00003-of-00004.safetensors:  45% 2.21G/4.92G [00:14<00:14, 183MB/s]
#
#
#
# model-00002-of-00004.safetensors:  38% 1.88G/5.00G [00:15<00:32, 95.1MB/s]
# model-00003-of-00004.safetensors:  46% 2.28G/4.92G [00:15<00:17, 147MB/s]
#
#
#
# model-00002-of-00004.safetensors:  42% 2.08G/5.00G [00:15<00:18, 160MB/s]
# model-00003-of-00004.safetensors:  48% 2.35G/4.92G [00:16<00:18, 142MB/s]
#
#
#
# model-00002-of-00004.safetensors:  44% 2.21G/5.00G [00:18<00:28, 96.6MB/s]
# model-00003-of-00004.safetensors:  51% 2.49G/4.92G [00:18<00:27, 87.8MB/s]
#
#
#
# model-00002-of-00004.safetensors:  48% 2.42G/5.00G [00:18<00:16, 155MB/s]
# model-00003-of-00004.safetensors:  53% 2.62G/4.92G [00:18<00:17, 133MB/s]
# model-00003-of-00004.safetensors:  55% 2.69G/4.92G [00:18<00:14, 159MB/s]
#
#
# model-00004-of-00004.safetensors: 100% 1.17G/1.17G [00:18<00:00, 62.4MB/s]
#
# model-00003-of-00004.safetensors:  56% 2.75G/4.92G [00:18<00:11, 186MB/s]
# model-00003-of-00004.safetensors:  59% 2.89G/4.92G [00:19<00:07, 263MB/s]
#
#
#
# model-00002-of-00004.safetensors:  51% 2.55G/5.00G [00:19<00:15, 162MB/s]
#
#
#
# model-00002-of-00004.safetensors:  52% 2.62G/5.00G [00:19<00:13, 177MB/s]
# model-00003-of-00004.safetensors:  61% 3.02G/4.92G [00:19<00:07, 260MB/s]
#
#
#
# model-00002-of-00004.safetensors:  54% 2.69G/5.00G [00:19<00:11, 200MB/s]
# model-00003-of-00004.safetensors:  63% 3.09G/4.92G [00:19<00:06, 264MB/s]
# model-00003-of-00004.safetensors:  64% 3.16G/4.92G [00:20<00:06, 275MB/s]
#
#
#
# model-00002-of-00004.safetensors:  56% 2.82G/5.00G [00:20<00:09, 232MB/s]
# model-00003-of-00004.safetensors:  66% 3.22G/4.92G [00:20<00:06, 259MB/s]
#
#
#
# model-00002-of-00004.safetensors:  58% 2.89G/5.00G [00:22<00:22, 92.8MB/s]
# model-00003-of-00004.safetensors:  67% 3.29G/4.92G [00:22<00:18, 88.0MB/s]
# model-00003-of-00004.safetensors:  71% 3.49G/4.92G [00:22<00:08, 172MB/s]
#
#
#
# model-00002-of-00004.safetensors:  63% 3.16G/5.00G [00:22<00:09, 186MB/s]
#
#
#
# model-00002-of-00004.safetensors:  66% 3.29G/5.00G [00:22<00:07, 230MB/s]
# model-00003-of-00004.safetensors:  74% 3.62G/4.92G [00:22<00:05, 221MB/s]
#
#
#
# model-00002-of-00004.safetensors:  68% 3.42G/5.00G [00:23<00:05, 290MB/s]
# model-00003-of-00004.safetensors:  76% 3.76G/4.92G [00:23<00:04, 237MB/s]
# model-00003-of-00004.safetensors:  78% 3.83G/4.92G [00:23<00:04, 237MB/s]
#
#
#
# model-00002-of-00004.safetensors:  71% 3.56G/5.00G [00:23<00:06, 228MB/s]
# model-00003-of-00004.safetensors:  79% 3.89G/4.92G [00:24<00:04, 222MB/s]
#
# model-00001-of-00004.safetensors:   4% 203M/4.98G [00:24<07:48, 10.2MB/s]
#
#
#
# model-00002-of-00004.safetensors:  73% 3.63G/5.00G [00:24<00:06, 218MB/s]
# model-00003-of-00004.safetensors:  81% 3.96G/4.92G [00:24<00:04, 212MB/s]
#
#
#
# model-00002-of-00004.safetensors:  74% 3.69G/5.00G [00:26<00:13, 94.6MB/s]
# model-00003-of-00004.safetensors:  82% 4.03G/4.92G [00:26<00:10, 83.8MB/s]
#
# model-00001-of-00004.safetensors:   4% 212M/4.98G [00:26<09:03, 8.77MB/s]
#
#
#
# model-00002-of-00004.safetensors:  78% 3.89G/5.00G [00:26<00:06, 164MB/s]
#
#
#
# model-00002-of-00004.safetensors:  81% 4.03G/5.00G [00:26<00:04, 222MB/s]
# model-00003-of-00004.safetensors:  85% 4.18G/4.92G [00:27<00:05, 129MB/s]
#
#
#
# model-00002-of-00004.safetensors:  83% 4.16G/5.00G [00:27<00:02, 280MB/s]
# model-00003-of-00004.safetensors:  86% 4.25G/4.92G [00:27<00:04, 141MB/s]
#
#
#
# model-00002-of-00004.safetensors:  86% 4.29G/5.00G [00:27<00:02, 281MB/s]
# model-00003-of-00004.safetensors:  88% 4.32G/4.92G [00:27<00:03, 164MB/s]
#
# model-00001-of-00004.safetensors:   5% 238M/4.98G [00:27<07:28, 10.6MB/s]
#
# model-00001-of-00004.safetensors:   7% 346M/4.98G [00:27<03:02, 25.4MB/s]
# model-00003-of-00004.safetensors:  89% 4.38G/4.92G [00:27<00:02, 187MB/s]
# model-00003-of-00004.safetensors:  91% 4.45G/4.92G [00:28<00:02, 207MB/s]
#
# model-00001-of-00004.safetensors:   8% 413M/4.98G [00:28<02:11, 34.8MB/s]
#
#
#
# model-00002-of-00004.safetensors:  88% 4.40G/5.00G [00:28<00:02, 210MB/s]
# model-00003-of-00004.safetensors:  92% 4.52G/4.92G [00:28<00:02, 178MB/s]
#
#
#
# model-00002-of-00004.safetensors:  89% 4.47G/5.00G [00:30<00:05, 97.8MB/s]
#
# model-00001-of-00004.safetensors:  10% 480M/4.98G [00:30<02:19, 32.3MB/s]
#
#
#
# model-00002-of-00004.safetensors:  93% 4.67G/5.00G [00:30<00:01, 167MB/s]
#
# model-00001-of-00004.safetensors:  11% 557M/4.98G [00:30<01:32, 48.0MB/s]
# model-00003-of-00004.safetensors:  93% 4.58G/4.92G [00:30<00:04, 71.3MB/s]
#
#
#
# model-00002-of-00004.safetensors:  97% 4.87G/5.00G [00:31<00:00, 251MB/s]
#
# model-00001-of-00004.safetensors:  13% 626M/4.98G [00:31<01:07, 64.6MB/s]
#
# model-00001-of-00004.safetensors:  14% 686M/4.98G [00:31<00:50, 85.7MB/s]
#
# model-00001-of-00004.safetensors:  15% 754M/4.98G [00:31<00:39, 107MB/s]
#
# model-00001-of-00004.safetensors:  20% 1.00G/4.98G [00:31<00:17, 225MB/s]
#
# model-00001-of-00004.safetensors:  21% 1.07G/4.98G [00:32<00:15, 246MB/s]
# model-00003-of-00004.safetensors:  95% 4.65G/4.92G [00:32<00:04, 60.8MB/s]
#
# model-00001-of-00004.safetensors:  23% 1.16G/4.98G [00:32<00:15, 247MB/s]
# model-00003-of-00004.safetensors:  96% 4.72G/4.92G [00:34<00:04, 45.2MB/s]
#
# model-00001-of-00004.safetensors:  26% 1.29G/4.98G [00:34<00:33, 110MB/s]
#
# model-00001-of-00004.safetensors:  29% 1.43G/4.98G [00:34<00:22, 159MB/s]
#
# model-00001-of-00004.safetensors:  33% 1.63G/4.98G [00:35<00:13, 257MB/s]
#
#
#
# model-00002-of-00004.safetensors: 100% 5.00G/5.00G [00:35<00:00, 141MB/s]
#
#
# model-00001-of-00004.safetensors:  36% 1.77G/4.98G [00:35<00:11, 282MB/s]
#
# model-00001-of-00004.safetensors:  40% 2.01G/4.98G [00:35<00:07, 418MB/s]
# model-00003-of-00004.safetensors:  99% 4.85G/4.92G [00:35<00:01, 65.8MB/s]
#
# model-00001-of-00004.safetensors:  44% 2.17G/4.98G [00:35<00:05, 515MB/s]
#
# model-00001-of-00004.safetensors:  46% 2.29G/4.98G [00:35<00:04, 571MB/s]
#
# model-00001-of-00004.safetensors:  49% 2.42G/4.98G [00:36<00:06, 425MB/s]
#
# model-00001-of-00004.safetensors:  51% 2.52G/4.98G [00:36<00:05, 422MB/s]
#
# model-00001-of-00004.safetensors:  52% 2.59G/4.98G [00:37<00:09, 248MB/s]
#
# model-00001-of-00004.safetensors:  53% 2.66G/4.98G [00:39<00:18, 128MB/s]
#
# model-00001-of-00004.safetensors:  57% 2.83G/4.98G [00:39<00:10, 211MB/s]
#
# model-00001-of-00004.safetensors:  61% 3.04G/4.98G [00:39<00:05, 330MB/s]
#
# model-00001-of-00004.safetensors:  65% 3.23G/4.98G [00:39<00:03, 460MB/s]
#
# model-00001-of-00004.safetensors:  68% 3.38G/4.98G [00:39<00:02, 549MB/s]
#
# model-00001-of-00004.safetensors:  71% 3.51G/4.98G [00:39<00:02, 615MB/s]
#
# model-00001-of-00004.safetensors:  73% 3.65G/4.98G [00:40<00:04, 272MB/s]
#
# model-00001-of-00004.safetensors:  76% 3.79G/4.98G [00:41<00:03, 358MB/s]
#
# model-00001-of-00004.safetensors:  80% 3.99G/4.98G [00:41<00:02, 461MB/s]
#
# model-00001-of-00004.safetensors:  83% 4.13G/4.98G [00:41<00:01, 542MB/s]
#
# model-00001-of-00004.safetensors:  86% 4.26G/4.98G [00:41<00:01, 542MB/s]
#
# model-00001-of-00004.safetensors:  88% 4.36G/4.98G [00:41<00:01, 459MB/s]
# model-00003-of-00004.safetensors: 100% 4.92G/4.92G [00:42<00:00, 117MB/s]
#
#
# model-00001-of-00004.safetensors:  90% 4.49G/4.98G [00:42<00:01, 466MB/s]
#
# model-00001-of-00004.safetensors:  93% 4.62G/4.98G [00:42<00:00, 500MB/s]
#
# model-00001-of-00004.safetensors:  94% 4.69G/4.98G [00:42<00:00, 476MB/s]
#
# model-00001-of-00004.safetensors:  96% 4.78G/4.98G [00:42<00:00, 452MB/s]
#
# model-00001-of-00004.safetensors:  97% 4.84G/4.98G [00:42<00:00, 434MB/s]
#
# model-00001-of-00004.safetensors:  99% 4.91G/4.98G [00:43<00:00, 409MB/s]
#
# model-00001-of-00004.safetensors: 100% 4.98G/4.98G [00:43<00:00, 115MB/s]
# Fetching 4 files: 100% 4/4 [00:43<00:00, 10.91s/it]
# Loading checkpoint shards: 100% 4/4 [00:07<00:00,  1.94s/it]
# generation_config.json: 100% 187/187 [00:00<00:00, 1.81MB/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     2600:1700:78e1:481f:9114:9187:7ef8:4d8a:0 - "OPTIONS /recommend HTTP/1.1" 200 OK
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# INFO:     2600:1700:78e1:481f:9114:9187:7ef8:4d8a:0 - "POST /recommend HTTP/1.1" 200 OK
# INFO:     2600:1700:78e1:481f:9114:9187:7ef8:4d8a:0 - "GET /info/refs?service=git-upload-pack HTTP/1.1" 404 Not Found
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# INFO:     2600:1700:78e1:481f:9114:9187:7ef8:4d8a:0 - "POST /recommend HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Finished server process [1556]
# ERROR:    Traceback (most recent call last):
#   File "/usr/lib/python3.12/asyncio/runners.py", line 195, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 678, in run_until_complete
#     self.run_forever()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.12/dist-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#          ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/contextlib.py", line 144, in __exit__
#     next(self.gen)
#   File "/usr/local/lib/python3.12/dist-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
#   File "/usr/lib/python3.12/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/usr/local/lib/python3.12/dist-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/queues.py", line 158, in get
#     await getter
# asyncio.exceptions.CancelledError
