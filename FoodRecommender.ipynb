# %% [markdown]
# <a href="https://colab.research.google.com/github/Albrrr/Food-Recommender/blob/main/FoodRecommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Food Recommender Backend Hosting
# - We are use colab for a more powerful GPU

# %% [markdown]
# Clone repo

# %%
# !git clone https://github.com/Albrrr/Food-Recommender.git
# %cd Food-Recommender
# Out:
# Cloning into 'Food-Recommender'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 80 (delta 36), reused 75 (delta 32), pack-reused 0 (from 0)
# Receiving objects: 100% (80/80), 1.97 MiB | 8.07 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/Food-Recommender/Food-Recommender/Food-Recommender/Food-Recommender

# %% [markdown]
# Install Dependencies

# %%
# !pip install -r backend/requirements.txt

# %% [markdown]
# Get tokens from secrets

# %%
from google.colab import userdata
import os

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
os.environ["NGROK_AUTHTOKEN"] = userdata.get("NGROK_AUTHTOKEN")
os.environ["USE_NGROK"] = "1"

# %% [markdown]
# Start backend

# %%
# !python backend/colab_run.py
# Out:
# Public URL: https://phenotypically-multiperforate-rodolfo.ngrok-free.dev
# Set your frontend API base to this URL (no trailing slash).
# INFO:     Started server process [40090]
# INFO:     Waiting for application startup.
# /content/Food-Recommender/Food-Recommender/Food-Recommender/Food-Recommender/backend/app.py:50: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# 2025-12-29 07:23:07.245263: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# ...
